# %%
#Linear Regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
heart_file1=pd.read_csv("/content/heart.csv")
heart_file1.head(10)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# ...

# %%
heart_file2=pd.read_csv("/content/heart.csv")
heart_file2.tail(10)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 293   67    1   2     152   212    0        0       150     0      0.8    1
# 294   44    1   0     120   169    0        1       144     1      2.8    0
# 295   63    1   0     140   187    0        0       144     1      4.0    2
# 296   63    0   0     124   197    0        1       136     1      0.0    1
# 297   59    1   0     164   176    1        0        90     0      1.0    1
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 293    0      3       0
# 294    0      1       0
# 295    2      3       0
# 296    0      2       0
# ...

# %%
heart_file1=pd.read_csv("/content/heart.csv")
heart_file1.shape
# Out:
# (303, 14)

# %%
heart_file2=pd.read_csv("/content/heart.csv")
heart_file2.shape
# Out:
# (303, 14)

# %%
firstfile_data=heart_file1.head(10)
secondfile_data=heart_file2.head(10)
r=pd.concat([firstfile_data,secondfile_data],axis=0)
r.to_csv("final heart file.csv")
print(r)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
# 5   57    1   0     140   192    0        1       148     0      0.4    1
# 6   56    0   1     140   294    0        0       153     0      1.3    1
# 7   44    1   1     120   263    0        1       173     0      0.0    2
# 8   52    1   2     172   199    1        1       162     0      0.5    2
# 9   57    1   2     150   168    0        1       174     0      1.6    2
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# ...

# %%
data=pd.read_csv("/content/final heart file.csv")
print(data)
# Out:
#     Unnamed: 0  age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  \
# 0            0   63    1   3     145   233    1        0       150     0
# 1            1   37    1   2     130   250    0        1       187     0
# 2            2   41    0   1     130   204    0        0       172     0
# 3            3   56    1   1     120   236    0        1       178     0
# 4            4   57    0   0     120   354    0        1       163     1
# 5            5   57    1   0     140   192    0        1       148     0
# 6            6   56    0   1     140   294    0        0       153     0
# 7            7   44    1   1     120   263    0        1       173     0
# 8            8   52    1   2     172   199    1        1       162     0
# 9            9   57    1   2     150   168    0        1       174     0
# 10           0   63    1   3     145   233    1        0       150     0
# 11           1   37    1   2     130   250    0        1       187     0
# ...

# %%
data=pd.read_csv("/content/final heart file.csv")
print(data.groupby(['restecg'])['fbs'].count())
data.groupby(['restecg'])['fbs'].count().plot(kind="bar")
plt.show()
# Out:
# restecg
# 0     6
# 1    14
# Name: fbs, dtype: int64

# %%
print(data.groupby(['fbs'])['restecg'].count())
print("0 = Fail\n1 = Pass")
data.groupby(['fbs'])['restecg'].count().plot(kind="pie")
plt.title("fbs and restecg",size=20)
plt.show()
# Out:
# fbs
# 0    16
# 1     4
# Name: restecg, dtype: int64
# 0 = Fail
# 1 = Pass

# %%
data=r.drop(["sex","cp","trtbps","fbs","restecg","thalachh","exng","oldpeak","caa","thall","output","age"], axis=1)
data.head(20)
# Out:
#    chol  slp
# 0   233    0
# 1   250    0
# 2   204    2
# 3   236    2
# 4   354    2
# 5   192    1
# 6   294    1
# 7   263    2
# 8   199    2
# 9   168    2
# 0   233    0
# 1   250    0
# 2   204    2
# 3   236    2
# 4   354    2
# 5   192    1
# 6   294    1
# 7   263    2
# 8   199    2
# 9   168    2

# %%
data=data.sample(frac=1)
data.head(20)
# Out:
#    chol  slp
# 6   294    1
# 1   250    0
# 8   199    2
# 9   168    2
# 7   263    2
# 9   168    2
# 5   192    1
# 4   354    2
# 5   192    1
# 0   233    0
# 3   236    2
# 1   250    0
# 4   354    2
# 2   204    2
# 0   233    0
# 8   199    2
# 2   204    2
# 7   263    2
# 6   294    1
# 3   236    2

# %%
data.isnull().sum()
# Out:
# chol    0
# slp     0
# dtype: int64

# %%
x=data["slp"]
y=data["chol"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
x_train = np.array(x_train)
x_test = np.array(x_test)

# %%
print(f"Type of x_train elements: {type(x_train[0])}")
print(f"Type of x_test elements: {type(x_test[0])}")
# Out:
# Type of x_train elements: <class 'numpy.int64'>
# Type of x_test elements: <class 'numpy.int64'>

# %%
if type(x_train[0]) != str or type(x_test[0]) != str:
  x_train = [str(x) for x in x_train]
  x_test = [str(x) for x in x_test]

# %%
import string #to deal with text data
import numpy as np
x_train = [str(x) for x in x_train]
vector = TfidfVectorizer()
xv_train=vector.fit_transform(x_train)
xv_test=vector.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-6d4e511dd73c> in <cell line: 5>()
#       3 x_train = [str(x) for x in x_train]
#       4 vector = TfidfVectorizer()
# ----> 5 xv_train=vector.fit_transform(x_train)
#       6 xv_test=vector.transform(x_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2131             sublinear_tf=self.sublinear_tf,
#    2132         )
# -> 2133         X = super().fit_transform(raw_documents)
#    2134         self._tfidf.fit(X)
#    2135         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1386                     break
#    1387
# ...
